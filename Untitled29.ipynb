# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

loan_df = pd.read_csv("loan_data.csv")

loan_df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
# https://www.datacamp.com/tutorial/chatgpt-data-science-projects

# %%
# Display the number of rows and columns in the dataset
print("Number of rows and columns:", loan_df.shape)

# Display summary statistics for numerical variables
print(loan_df.describe())
# Out:
# Number of rows and columns: (9578, 14)
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# ...

# %%
print(loan_df.isnull().sum())
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
sns.countplot(x="not.fully.paid", data=loan_df)
plt.show()

# %%
corr = loan_df.corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()
# Out:
# C:\Users\Prashant\AppData\Local\Temp\ipykernel_11856\288132557.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = loan_df.corr()

# %%
sns.countplot(x="purpose", data=loan_df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x="purpose", y="int.rate", data=loan_df)
plt.xticks(rotation=90)
plt.show()

# %%
data = pd.read_csv('loan_data.csv')
data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
# # Step 2: Data Cleaning
# # Handle Missing Values
# data.dropna(inplace=True)  # Remove rows with any missing values
# data.fillna(value, inplace=True)  # Fill missing values with a specific value


data.dropna()
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
print(data.fillna(00 , inplace=True))
# Out:
# None

# %%
# # Remove Duplicates
# data.drop_duplicates(inplace=True)
data.drop_duplicates()
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
data['credit.policy'] = some_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 data['credit.policy'] = some_values
#
# NameError: name 'some_values' is not defined

# %%
# Step 3: Adding and Deleting Columns and Rows
# data['new_column'] = some_values  # Add a new column with specified values
# data.drop(columns=['column_to_drop'], inplace=True)  # Delete a column
# data = data.drop(index=[row_indices])  # Delete specific rows by index


data.drop(columns=['credit.policy'])
# Out:
#                  purpose  int.rate  installment  log.annual.inc    dti  fico  \
# 0     debt_consolidation    0.1189       829.10       11.350407  19.48   737
# 1            credit_card    0.1071       228.22       11.082143  14.29   707
# 2     debt_consolidation    0.1357       366.86       10.373491  11.63   682
# 3     debt_consolidation    0.1008       162.34       11.350407   8.10   712
# 4            credit_card    0.1426       102.92       11.299732  14.97   667
# ...                  ...       ...          ...             ...    ...   ...
# 9573           all_other    0.1461       344.76       12.180755  10.39   672
# 9574           all_other    0.1253       257.70       11.141862   0.21   722
# 9575  debt_consolidation    0.1071        97.81       10.596635  13.09   687
# 9576    home_improvement    0.1600       351.58       10.819778  19.18   692
# 9577  debt_consolidation    0.1392       853.43       11.264464  16.28   732
#
# ...

# %%
data = data.drop(index=[0])
data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 1                 1         credit_card    0.1071       228.22
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# 5                 1         credit_card    0.0788       125.13
# 6                 1  debt_consolidation    0.1496       194.02
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 1          11.082143  14.29   707        2760.000000      33623        76.7
# ...

# %%
# Step 4: Filtering Data
filtered_data = data[data['int.rate'] > 0.1]
filtered_data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 1                 1         credit_card    0.1071       228.22
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# 6                 1  debt_consolidation    0.1496       194.02
# 7                 1           all_other    0.1114       131.22
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 1          11.082143  14.29   707        2760.000000      33623        76.7
# ...
